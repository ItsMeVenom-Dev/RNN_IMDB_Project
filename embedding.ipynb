# %%
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
vocab_size=10000

# %%
words=[one_hot(words,vocab_size) for words in sent]

# %%
words
# Out:
# [[5466, 1489, 9131, 9283],
#  [5466, 1489, 9131, 1801],
#  [5466, 2240, 9131, 9442],
#  [7374, 9554, 8188, 5696, 9969],
#  [7374, 9554, 8188, 5696, 7786],
#  [7635, 5466, 2256, 9131, 7731],
#  [7188, 1267, 4797, 5696]]

# %%
import tensorflow as tf
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length=8
embedded_docs=pad_sequences(words,padding='pre',maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 5466, 1489, 9131, 9283],
#        [   0,    0,    0,    0, 5466, 1489, 9131, 1801],
#        [   0,    0,    0,    0, 5466, 2240, 9131, 9442],
#        [   0,    0,    0, 7374, 9554, 8188, 5696, 9969],
#        [   0,    0,    0, 7374, 9554, 8188, 5696, 7786],
#        [   0,    0,    0, 7635, 5466, 2256, 9131, 7731],
#        [   0,    0,    0,    0, 7188, 1267, 4797, 5696]], dtype=int32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
dim=10
model=Sequential()
model.add(Embedding(vocab_size,dim,input_length=sent_length))
# Out:
# d:\DEEP LEARNING NLP\.venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# array([[[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [-0.01593486,  0.00027628, -0.00201722, -0.02440768,
#          -0.02244092,  0.01715323, -0.02819506, -0.02463834,
#           0.04254563,  0.00524247],
#         [-0.03434696, -0.02949742, -0.0020202 ,  0.00716435,
#          -0.04646806, -0.02707543,  0.04666099, -0.01394099,
#          -0.04623466,  0.02667204],
#         [ 0.0263514 , -0.01637612,  0.0227687 , -0.04419702,
#           0.04325106, -0.02628957,  0.02794835, -0.04737154,
#          -0.01255605, -0.03005784],
#         [ 0.03326162,  0.00734379,  0.03537038, -0.01193646,
#           0.02998508,  0.02293741,  0.03887856,  0.00674614,
#           0.01897195,  0.03172379]],
#
#        [[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [-0.01593486,  0.00027628, -0.00201722, -0.02440768,
#          -0.02244092,  0.01715323, -0.02819506, -0.02463834,
#           0.04254563,  0.00524247],
#         [-0.03434696, -0.02949742, -0.0020202 ,  0.00716435,
#          -0.04646806, -0.02707543,  0.04666099, -0.01394099,
#          -0.04623466,  0.02667204],
#         [ 0.0263514 , -0.01637612,  0.0227687 , -0.04419702,
#           0.04325106, -0.02628957,  0.02794835, -0.04737154,
#          -0.01255605, -0.03005784],
#         [ 0.02855091, -0.01201272,  0.02160469, -0.01772834,
#           0.016052  , -0.04050957, -0.02107475, -0.03674388,
#          -0.04727781,  0.00768017]],
#
#        [[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [-0.01593486,  0.00027628, -0.00201722, -0.02440768,
#          -0.02244092,  0.01715323, -0.02819506, -0.02463834,
#           0.04254563,  0.00524247],
#         [-0.02125136, -0.00318959, -0.00549526,  0.02989987,
#          -0.02984527, -0.03747381, -0.01203462,  0.03928432,
#          -0.03802564, -0.0422202 ],
#         [ 0.0263514 , -0.01637612,  0.0227687 , -0.04419702,
#           0.04325106, -0.02628957,  0.02794835, -0.04737154,
#          -0.01255605, -0.03005784],
#         [ 0.02210094,  0.0036775 ,  0.00111114, -0.0209471 ,
#          -0.03966596, -0.03051498, -0.02686303,  0.0455111 ,
#           0.03229551,  0.0008283 ]],
#
#        [[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [-0.01401925,  0.02643523, -0.01304843,  0.03212914,
#           0.01659247,  0.04925951, -0.00692672, -0.03217542,
#           0.00646105,  0.01720568],
#         [ 0.03234157,  0.01188974,  0.0104712 ,  0.01215215,
#           0.01541522,  0.02850034, -0.00653164, -0.03871886,
#           0.03128595, -0.02340106],
#         [ 0.01434492, -0.01184132, -0.01769239,  0.00405029,
#          -0.04735558, -0.03076308,  0.01117199,  0.04300734,
#           0.04966999,  0.0482217 ],
#         [ 0.02328262,  0.02939321,  0.03236889, -0.01087695,
#          -0.00071386, -0.00933643, -0.03128004,  0.03696885,
#          -0.04224652, -0.0433001 ],
#         [ 0.04922325, -0.00927907, -0.04293078,  0.04642762,
#           0.03263917,  0.02015945,  0.01579586,  0.0383015 ,
#           0.01215994,  0.04264839]],
#
#        [[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [-0.01401925,  0.02643523, -0.01304843,  0.03212914,
#           0.01659247,  0.04925951, -0.00692672, -0.03217542,
#           0.00646105,  0.01720568],
#         [ 0.03234157,  0.01188974,  0.0104712 ,  0.01215215,
#           0.01541522,  0.02850034, -0.00653164, -0.03871886,
#           0.03128595, -0.02340106],
#         [ 0.01434492, -0.01184132, -0.01769239,  0.00405029,
#          -0.04735558, -0.03076308,  0.01117199,  0.04300734,
#           0.04966999,  0.0482217 ],
#         [ 0.02328262,  0.02939321,  0.03236889, -0.01087695,
#          -0.00071386, -0.00933643, -0.03128004,  0.03696885,
#          -0.04224652, -0.0433001 ],
#         [-0.02968423,  0.04296089, -0.02082292,  0.01993762,
#           0.00325524,  0.01725012,  0.03470155, -0.01783551,
#          -0.0256281 ,  0.02779922]],
#
#        [[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.02809999, -0.04384904,  0.031016  ,  0.01987991,
#           0.00688032,  0.02453125, -0.02751172,  0.04615078,
#          -0.01746658, -0.02874286],
#         [-0.01593486,  0.00027628, -0.00201722, -0.02440768,
#          -0.02244092,  0.01715323, -0.02819506, -0.02463834,
#           0.04254563,  0.00524247],
#         [-0.02014852,  0.0159305 ,  0.00392075, -0.00394856,
#           0.02637753, -0.04361625, -0.04752308,  0.01894665,
#           0.00545494, -0.0170531 ],
#         [ 0.0263514 , -0.01637612,  0.0227687 , -0.04419702,
#           0.04325106, -0.02628957,  0.02794835, -0.04737154,
#          -0.01255605, -0.03005784],
#         [-0.04598282,  0.02882612, -0.00983163, -0.04205129,
#          -0.03678549,  0.00472552, -0.04247855,  0.01699437,
#           0.04946964,  0.00832014]],
#
#        [[ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.03162906, -0.03519461, -0.0270699 , -0.01584587,
#          -0.0034977 , -0.00661677, -0.00063901,  0.01851617,
#           0.04568833,  0.00556837],
#         [ 0.01610902, -0.00080377,  0.00796944, -0.03284781,
#           0.02771467, -0.02570484,  0.02366875, -0.04475987,
#           0.03785597, -0.01353332],
#         [ 0.03437013, -0.00776446, -0.0124015 , -0.0164729 ,
#          -0.03215446, -0.04999761, -0.03198965, -0.02560884,
#          -0.03395878,  0.0355202 ],
#         [ 0.00685973, -0.01279795, -0.02941368,  0.01851448,
#          -0.04623675,  0.01322984, -0.01906053,  0.01388725,
#           0.03741754, -0.02734691],
#         [ 0.02328262,  0.02939321,  0.03236889, -0.01087695,
#          -0.00071386, -0.00933643, -0.03128004,  0.03696885,
#          -0.04224652, -0.0433001 ]]], dtype=float32)

# %%
model.predict(embedded_docs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 from matplotlib import axes, axis
# ----> 4 model.predict(embedded_docs[0],axis=0)
#
# File d:\DEEP LEARNING NLP\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File d:\DEEP LEARNING NLP\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: TensorFlowTrainer.predict() got an unexpected keyword argument 'axis'
